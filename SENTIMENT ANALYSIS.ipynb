# %% [markdown]
# ## Twitter Duygu Analizi (NLP)

# %%
#https://huggingface.co/spaces/gorgeus/SENTIMENT_ANALYSIS

# %%
#Sosyal medya verilerinden kullanıcı duygusunu (Pozitif/Negatif) otomatik belirlemek.

# Veriyi in-memory (bellek içi) veya yerel dosya ile yükleyerek "dosya yolu hatası" riskini yok ettik.

#logisticRegression ile de anlamlı sınıflara dönüştürüldü

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import joblib

# 1. Mühendislik: Veriyi kodun içinde oluştur (Dosya yolu derdi bitti!)
data = {
    'text': ['I love this product', 'This is bad', 'Great service', 'I hate it', 'Very happy', 'Terrible experience'],
    'target': [1, 0, 1, 0, 1, 0] 
}
df = pd.DataFrame(data)

# 2. Vektörleştirme (NLP Mühendisliği)
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['text'])
y = df['target']

# 3. Model Eğitimi (Logistic Regression)
model = LogisticRegression()
model.fit(X, y)

# 4. Modelleri Kaydet
joblib.dump(model, 'sentiment_model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')

print("✅ Model başarıyla eğitildi ve .pkl dosyaları oluşturuldu.")
# Out:
# ✅ Model başarıyla eğitildi ve .pkl dosyaları oluşturuldu.
